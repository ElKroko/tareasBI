# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# Path: taller_integrador.ipynb
# Función para leer el archivo de datos

def xls_to_pd(xls_file):
    df = pd.read_excel(xls_file)
    return df


df = xls_to_pd('Taller.xls').set_index('FECHA VENTA').drop(['Unnamed: 0', "Unnamed: 9"], axis=1)
df.columns
display(df)

## Check duplicates and Nan values

print("Nan values: ", df.isnull().sum().sum())
print("Duplicated values: ", df.duplicated().sum())

## Print all unique values of "MES" column

print("Unique values of 'MES' column: ", df['MES'].unique())







df.to_csv('Taller.csv')
# Out:
#              NUMERO FACTURA  DESPACHO        MES  RUT CLIENTE  \
# FECHA VENTA
# 2016-01-01           123471    163452      ENERO  81675600 -6
# 2016-01-02           123472    163451      ENERO  81675600 -6
# 2016-01-03           123473    163450      ENERO  81675600 -6
# 2016-01-04           123474    163449      ENERO  81675600 -6
# 2016-01-05           123447    163504      ENERO  81148200 -5
# ...                     ...       ...        ...          ...
# 2018-02-27           124607    164201  DICIEMBRE  81148200 -5
# 2018-02-28           124597    164766  DICIEMBRE  76423701 -3
# 2018-03-01           124596    163750  DICIEMBRE  76466068 -4
# 2018-03-02            20261    162439  DICIEMBRE  81148200 -5
# 2018-03-03            20259    164280  DICIEMBRE  76264035 -K
#
#                                            NOMBRE                ADUANA  \
# FECHA VENTA
# 2016-01-01                  COMERCIALIZADORA S.A.  VALPARAISO
# ...

# %%
## Check value counts of unique values of "DESPACHO" and "NUMERO FACTURA" columns

print("Value counts of 'DESPACHO' column: ", df['DESPACHO'].value_counts())
print("Value counts of 'NUMERO FACTURA' column: ", df['NUMERO FACTURA'].value_counts())

## Print the "DESPACHO" values that have more than 1 value count

display("DESPACHO values that have more than 1 value count: ", df['DESPACHO'].value_counts()[df['DESPACHO'].value_counts() > 1])

## Get the rows that have the value counts of "DESPACHO" column greater than 1

df_despacho = df[df['DESPACHO'].isin(df['DESPACHO'].value_counts()[df['DESPACHO'].value_counts() > 1].index)]



display(df_despacho.set_index("DESPACHO").sort_values('DESPACHO'))
df_despacho.shape
# Out:
# Value counts of 'DESPACHO' column:  163111    3
# 162872    3
# 163523    3
# 164169    3
# 163739    3
#          ..
# 163605    1
# 163665    1
# 163666    1
# 163703    1
# 164280    1
# Name: DESPACHO, Length: 780, dtype: int64
# Value counts of 'NUMERO FACTURA' column:  123471    1
# 20173     1
# 124246    1
# 124247    1
# 124248    1
#          ..
# 20099     1
# 20100     1
# 20101     1
# 20102     1
# 20259     1
# Name: NUMERO FACTURA, Length: 793, dtype: int64
# 'DESPACHO values that have more than 1 value count: '
# 163111    3
# 162872    3
# 163523    3
# 164169    3
# 163739    3
# 163283    2
# 164453    2
# 163106    2
# Name: DESPACHO, dtype: int64
#          FECHA VENTA  NUMERO FACTURA         MES  RUT CLIENTE  \
# DESPACHO
# 162872    2016-04-10          123632       MARZO  55555555 -6
# 162872    2017-07-12            4859   NOVIEMBRE  55555555 -6
# 162872    2016-05-23          123711       ABRIL  55555555 -6
# ...

# %%
df[df["NOMBRE"] == "BOPP CHILE S.A."]["HONORARIOS"].sum()
# Out:
# 4497460

# %%
# %pip install sqlalchemy mysqlclient
# Out:
# ...
#                                               0.0/200.0 kB ? eta -:--:--
#      -----                                   30.7/200.0 kB 1.3 MB/s eta 0:00:01
#      -------------                         71.7/200.0 kB 991.0 kB/s eta 0:00:01
#      -------------------------------------- 200.0/200.0 kB 2.4 MB/s eta 0:00:00
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
from sqlalchemy import create_engine

# Establece la conexión a la base de datos MySQL
engine = create_engine('mysql://root:1234@localhost/taller_practico')

# Carga el archivo CSV en un DataFrame de pandas
df = pd.read_csv('Taller.csv')

print(df.columns)
# Out:
# Index(['FECHA VENTA', 'NUMERO FACTURA', 'DESPACHO', 'MES', 'RUT CLIENTE',
#        'NOMBRE', 'ADUANA', 'DECLARACION', 'GASTO POR VENTA', 'HONORARIOS',
#        'EJECUTIVO'],
#       dtype='object')

# %%
# Guarda el DataFrame en la base de datos
df.to_sql('TallerDB', con=engine, if_exists='append', index=False)
# Out:
# C:\Users\n3mes\AppData\Local\Temp\ipykernel_36212\2633590452.py:2: UserWarning: The provided table name 'TallerDB' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   df.to_sql('TallerDB', con=engine, if_exists='append', index=False)
# 793
